# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
inspector = inspect(engine)
columns = inspector.get_columns('measurement')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
inspector = inspect(engine)
columns = inspector.get_columns('station')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results

# Calculate the date 1 year ago from the last data point in the database
end_date = session.query(Measurement.date).order_by(Measurement.date.desc()).first()
print(end_date)
# Out:
# ('2017-08-23',)

# %%
start_date = dt.date(2017, 8, 23) - dt.timedelta(days=365)
print(start_date)
# Out:
# 2016-08-23

# %%
# Perform a query to retrieve the data and precipitation scores
yearly_prcp = session.query(Measurement.prcp, Measurement.date).\
            filter(Measurement.date <= '2017-08-23').\
            filter(Measurement.date >= '2016-08-23').all()

yearly_prcp
# Out:
# [(0.0, '2016-08-23'),
#  (0.08, '2016-08-24'),
#  (0.08, '2016-08-25'),
#  (0.0, '2016-08-26'),
#  (0.0, '2016-08-27'),
#  (0.01, '2016-08-28'),
#  (0.0, '2016-08-29'),
#  (0.0, '2016-08-30'),
#  (0.13, '2016-08-31'),
#  (0.0, '2016-09-01'),
#  (0.0, '2016-09-02'),
#  (0.0, '2016-09-03'),
#  (0.03, '2016-09-04'),
#  (None, '2016-09-05'),
#  (None, '2016-09-06'),
#  (0.05, '2016-09-07'),
#  (0.0, '2016-09-08'),
#  (0.03, '2016-09-09'),
#  (0.0, '2016-09-10'),
#  (0.05, '2016-09-11'),
#  (0.0, '2016-09-12'),
#  (0.02, '2016-09-13'),
#  (1.32, '2016-09-14'),
#  (0.42, '2016-09-15'),
#  (0.06, '2016-09-16'),
#  (0.05, '2016-09-17'),
#  (0.0, '2016-09-18'),
#  (0.0, '2016-09-19'),
#  (0.0, '2016-09-20'),
#  (0.0, '2016-09-21'),
#  (0.02, '2016-09-22'),
#  (0.0, '2016-09-23'),
#  (0.0, '2016-09-24'),
#  (0.0, '2016-09-25'),
#  (0.06, '2016-09-26'),
#  (0.02, '2016-09-27'),
#  (0.0, '2016-09-28'),
#  (0.0, '2016-09-29'),
#  (0.0, '2016-09-30'),
#  (0.0, '2016-10-01'),
# ...

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
prcp_df = pd.DataFrame(yearly_prcp, columns=['precipitation', 'date'])
prcp_df.set_index('date', inplace=True)
# Sort the dataframe by date
prcp_df.sort_index(ascending=True, inplace=True)
prcp_df
# Out:
#             precipitation
# date
# 2016-08-23           0.00
# 2016-08-23            NaN
# 2016-08-23           1.79
# 2016-08-23           0.05
# 2016-08-23           0.15
# ...                   ...
# 2017-08-22           0.00
# 2017-08-23           0.00
# 2017-08-23           0.00
# 2017-08-23           0.08
# 2017-08-23           0.45
#
# [2230 rows x 1 columns]

# %%
# Use Pandas Plotting with Matplotlib to plot the data
ax = prcp_df.plot(y='precipitation', rot=90)
ax.set_ylabel('Inches')
ax.set_xlabel('Date')
plt.tight_layout()
plt.savefig('Images/precipiation.png')
plt.show()

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
prcp_df.describe()
# Out:
#        precipitation
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %%
stations = session.query(Station.station).all()
print(stations)
# Out:
# [('USC00519397',), ('USC00513117',), ('USC00514830',), ('USC00517948',), ('USC00518838',), ('USC00519523',), ('USC00519281',), ('USC00511918',), ('USC00516128',)]

# %%
# Design a query to show how many stations are available in this dataset
station_count = session.query(Station.station).count()
station_count
# Out:
# 9

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
station_active = session.query(Measurement.station, func.count(Measurement.station)).\
                group_by(Measurement.station).order_by(func.count(Measurement.station).desc()).all()
station_active
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature of the most active station.
lowest_temp = session.query(func.min(Measurement.tobs)).\
            filter(Measurement.station == 'USC00519281').all()
lowest_temp
# Out:
# [(54.0)]

# %%
highest_temp = session.query(func.max(Measurement.tobs)).\
            filter(Measurement.station == 'USC00519281').all()
highest_temp
# Out:
# [(85.0)]

# %%
avg_temp = session.query(func.avg(Measurement.tobs)).\
            filter(Measurement.station == 'USC00519281').all()
avg_temp

print(f"The most active station was Station ID USC00519281. The lowest recorded temperature was {lowest_temp}, the highest recorded temperature was {highest_temp}, and the average temperature was {avg_temp}")
# Out:
# The most active station was Station ID USC00519281. The lowest recorded temperature was [(54.0,)], the highest recorded temperature was [(85.0,)], and the average temperature was [(71.66378066378067,)]

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
yearly_tobs = session.query(Measurement.station, Measurement.tobs).\
            filter(Measurement.date <= '2017-08-23').\
            filter(Measurement.date >= '2016-08-23').\
            filter(Measurement.station == 'USC00519281').all()

yearly_tobs
# Out:
# [('USC00519281', 77.0),
#  ('USC00519281', 77.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 75.0),
#  ('USC00519281', 73.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 77.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 73.0),
#  ('USC00519281', 74.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 79.0),
#  ('USC00519281', 77.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 76.0),
#  ('USC00519281', 79.0),
#  ('USC00519281', 75.0),
#  ('USC00519281', 79.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 79.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 76.0),
#  ('USC00519281', 74.0),
#  ('USC00519281', 77.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 79.0),
#  ('USC00519281', 79.0),
#  ('USC00519281', 77.0),
#  ('USC00519281', 80.0),
#  ('USC00519281', 78.0),
#  ('USC00519281', 78.0),
# ...

# %%
#Unpack tuples to store in dataframe
station_tobs = [x[1] for x in yearly_tobs]
station_tobs
station_id = [x[0] for x in yearly_tobs]
station_id
# Out:
# ['USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
#  'USC00519281',
# ...

# %%
#Store temperatures in dataframe
tobs_df = pd.DataFrame(yearly_tobs, columns = ['station_id', 'station_tobs'])
tobs_df.set_index('station_id', inplace=True)
tobs_df.head(20)
# Out:
#              station_tobs
# station_id
# USC00519281          77.0
# USC00519281          77.0
# USC00519281          80.0
# USC00519281          80.0
# USC00519281          75.0
# USC00519281          73.0
# USC00519281          78.0
# USC00519281          77.0
# USC00519281          78.0
# USC00519281          80.0
# USC00519281          80.0
# USC00519281          78.0
# USC00519281          78.0
# USC00519281          78.0
# USC00519281          73.0
# USC00519281          74.0
# USC00519281          80.0
# USC00519281          79.0
# USC00519281          77.0
# USC00519281          80.0

# %%
#Plot histogram
tobs_df.plot.hist(bins=12)
plt.xlabel('Temperature')
plt.legend(['tobs'])
plt.tight_layout()
plt.savefig('Images/Histogram.png')

# %% [markdown]
# ## Bonus Challenge Assignment

# %% [markdown]
# ## Temperature Analysis 1

# %%
#Identify the average temperature in June at all stations across all available years in the dataset. 
avg_june_temp = session.query(func.avg(Measurement.tobs)).\
                group_by(Measurement.station).filter(func.strftime("%m", Measurement.date) == '06').all()
avg_june_temp
# Out:
# [(74.13939393939394),
#  (74.05084745762711),
#  (76.00537634408602),
#  (71.9372197309417),
#  (76.6554054054054),
#  (73.39473684210526),
#  (73.27118644067797),
#  (77.55932203389831),
#  (76.66810344827586)]

# %%
#Do the same for December temperature.
avg_dec_temp = session.query(func.avg(Measurement.tobs)).\
            group_by(Measurement.station).filter(func.strftime("%m", Measurement.date) == '12').all()
avg_dec_temp
# Out:
# [(69.6842105263158),
#  (71.06944444444444),
#  (73.2247191011236),
#  (69.29126213592232),
#  (71.8348623853211),
#  (72.42105263157895),
#  (69.90322580645162),
#  (71.10952380952381),
#  (72.43333333333334)]

# %%
#Use the t-test to determine whether the difference in the means, if any, is statistically significant. 
#Will you use a paired t-test, or an unpaired t-test? Why?

#Paired t-test
stats.ttest_rel(avg_june_temp, avg_dec_temp)
# Out:
# Ttest_relResult(statistic=array([6.95696617]), pvalue=array([0.00011759]))

# %% [markdown]
# ## Temperature Analysis 2

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
#print(calc_temps('2012-02-28', '2012-03-05'))

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.
my_trip = calc_temps('2015-04-20', '2016-04-20')
my_trip
# Out:
# [(56.0, 74.29054054054055, 86.0)]

# %%
# Use np.ravel to unpack my_trip tuple so unique values can be used to create chart
trip = list(np.ravel(my_trip))
min_t = trip[0]
max_t = trip[2]
avg_t = trip[1]

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)
yerr = (max_t - min_t)
plt.figure(figsize=(3,8))
plt.bar(1, avg_t, color='darksalmon', alpha= 0.5)
plt.errorbar(1, avg_t, yerr=yerr, color='slategrey')
plt.xticks([])
plt.ylabel('Temp (F)')
plt.title('Trip Avg Temp')
plt.tight_layout()
plt.savefig('Images/TripAvgTemp.png')

# %% [markdown]
# ## Daily Rainfall Average

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation
my_trip_stations = session.query(Station.station, Station.name, Station.latitude, Station.longitude, Station.elevation,
                                func.sum(Measurement.prcp)).\
                    filter(Measurement.date >= '2015-04-20').filter(Measurement.date <= '2016-04-20').\
                    filter(Station.station == Measurement.station).group_by(Measurement.station).\
                    order_by(func.sum(Measurement.prcp).desc()).all()
my_trip_stations
# Out:
# [('USC00516128',
#   'MANOA LYON ARBO 785.2, HI US',
#   21.3331,
#   -157.8025,
#   152.4,
#   167.2000000000001),
#  ('USC00519281',
#   'WAIHEE 837.5, HI US',
#   21.45167,
#   -157.84888999999998,
#   32.9,
#   84.57),
#  ('USC00513117',
#   'KANEOHE 838.1, HI US',
#   21.4234,
#   -157.8015,
#   14.6,
#   55.13000000000002),
#  ('USC00519523',
#   'WAIMANALO EXPERIMENTAL FARM, HI US',
#   21.33556,
#   -157.71139,
#   19.5,
#   52.12999999999999),
#  ('USC00514830',
#   'KUALOA RANCH HEADQUARTERS 886.9, HI US',
#   21.5213,
#   -157.8374,
#   7.0,
#   42.43000000000001),
#  ('USC00519397',
#   'WAIKIKI 717.2, HI US',
#   21.2716,
#   -157.8168,
#   3.0,
#   16.299999999999986),
#  ('USC00511918',
#   'HONOLULU OBSERVATORY 702.2, HI US',
#   21.3152,
#   -157.9992,
#   0.9,
#   4.5200000000000005),
#  ('USC00517948',
#   'PEARL CITY, HI US',
#   21.3934,
#   -157.9751,
#   11.9,
#   3.3400000000000003),
# ...

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
#daily_normals("01-01")

# %%
# calculate the daily normals for your trip

# Set the start and end date of the trip
# Use the start and end date to create a range of dates
start_date = dt.datetime.strptime('2016-04-10', "%Y-%m-%d")
end_date = dt.datetime.strptime('2016-04-20', "%Y-%m-%d")

# push each tuple of calculations into a list called `normals`
normals = []
dates = []

indv_date = start_date

# Loop through the list of %m-%d strings and calculate the normals for each date
while indv_date <= end_date:
    dates.append(indv_date)
    daily_norm = indv_date.strftime("%m-%d")  # Stip off the year and save a list of %m-%d strings
    indv_date += dt.timedelta(1)
    normals.append(*daily_normals(daily_norm))
    
normals
# Out:
# [(64.0, 71.40350877192982, 79.0),
#  (65.0, 72.49180327868852, 82.0),
#  (65.0, 72.22413793103448, 80.0),
#  (64.0, 71.52542372881356, 79.0),
#  (65.0, 72.75, 81.0),
#  (61.0, 71.79310344827586, 79.0),
#  (62.0, 71.55357142857143, 81.0),
#  (65.0, 71.93103448275862, 77.0),
#  (67.0, 72.49152542372882, 77.0),
#  (65.0, 72.42105263157895, 83.0),
#  (64.0, 72.73684210526316, 80.0)]

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index
daily_normals_df = pd.DataFrame(normals, columns= ['tmin','tavg','tmax'])
daily_normals_df['Date'] = pd.to_datetime(dates)
daily_normals_df.set_index('Date', inplace=True)
daily_normals_df
# Out:
#             tmin       tavg  tmax
# Date
# 2016-04-10  64.0  71.403509  79.0
# 2016-04-11  65.0  72.491803  82.0
# 2016-04-12  65.0  72.224138  80.0
# 2016-04-13  64.0  71.525424  79.0
# 2016-04-14  65.0  72.750000  81.0
# 2016-04-15  61.0  71.793103  79.0
# 2016-04-16  62.0  71.553571  81.0
# 2016-04-17  65.0  71.931034  77.0
# 2016-04-18  67.0  72.491525  77.0
# 2016-04-19  65.0  72.421053  83.0
# 2016-04-20  64.0  72.736842  80.0

# %%
# Plot the daily normals as an area plot with `stacked=False`
import matplotlib.dates as mdates
ax = daily_normals_df.plot.area(stacked=False, alpha=0.25)
ax.set_xticks(daily_normals_df.index)
ax.set_xticklabels(daily_normals_df.index, rotation=45)
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))
ax.xaxis.set_minor_formatter(mdates.DateFormatter("%Y-%m-%d"))
ax.set_ylabel('Temperature')
plt.tight_layout()
plt.savefig('Images/DailyNormals.png')
plt.show()
